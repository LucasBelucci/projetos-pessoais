# %%
import pandas as pd

# %%
dados = pd.read_csv('Top_Anime_data.csv')
dados.head()
# Out:
#    Score  Popularity  Rank  Members  \
# 0   9.38         285     1      707
# 1   9.09           3     2        3
# 2   9.07          13     3        2
# 3   9.06         342     4      629
# 4   9.05          21     5        2
#
#                                          Description  \
# 0  During their decade-long quest to defeat the D...
# 1  After a horrific alchemy experiment goes wrong...
# 2  Eccentric scientist Rintarou Okabe has a never...
# 3  Gintoki, Shinpachi, and Kagura return as the f...
# 4  Seeking to restore humanity's diminishing hope...
#
#                                             Synonyms  \
# 0                             Frieren at the Funeral
# 1  Hagane no Renkinjutsushi: Fullmetal Alchemist,...
# 2                                        STEINS;GATE
# 3                                    Gintama' (2015)
# 4                               進撃の巨人 Season3 Part.2
#
#                           Japanese                           English  \
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Score        1000 non-null   float64
#  1   Popularity   1000 non-null   int64
#  2   Rank         1000 non-null   int64
#  3   Members      1000 non-null   int64
#  4   Description  1000 non-null   object
#  5   Synonyms     1000 non-null   object
#  6   Japanese     1000 non-null   object
#  7   English      999 non-null    object
#  8   Type         999 non-null    object
#  9   Eps          1000 non-null   object
#  10  Status       1000 non-null   object
#  11  Aired        1000 non-null   object
#  12  Premiered    1000 non-null   object
#  13  Broadcast    1000 non-null   object
#  14  Producers    1000 non-null   object
#  15  Licensors    1000 non-null   object
#  16  Studios      1000 non-null   object
#  17  Source       1000 non-null   object
# ...

# %%
dados.isnull().sum()
# Out:
# Score          0
# Popularity     0
# Rank           0
# Members        0
# Description    0
# Synonyms       0
# Japanese       0
# English        1
# Type           1
# Eps            0
# Status         0
# Aired          0
# Premiered      0
# Broadcast      0
# Producers      0
# Licensors      0
# Studios        0
# Source         0
# Genres         0
# Demographic    0
# Duration       0
# Rating         0
# dtype: int64

# %%
idx_type = dados[dados['Type'].isnull()].index
idx_english = dados[dados['English'].isnull()].index

# %%
print(f'Null type: {idx_type} / Null English: {idx_english}')
# Out:
# Null type: Index([48], dtype='int64') / Null English: Index([5], dtype='int64')

# %%
dados[dados['Type'].isnull()]
# Out:
#     Score  Popularity  Rank  Members  \
# 48   8.74        3051    49       52
#
#                                           Description     Synonyms  Japanese  \
# 48  Yabuki Joe is left downhearted and hopeless af...  Rocky Joe 2  あしたのジョー２
#
#              English Type                             Eps  ...  \
# 48  Tomorrow's Joe 2  NaN  El Campeón/ El mañana de Joe 2  ...
#
#           Premiered                     Broadcast  Producers Licensors  \
# 48  Finished Airing  Oct 13, 1980 to Aug 31, 1981  Fall 1980   Unknown
#
#      Studios                Source               Genres Demographic  \
# 48  Annapuru  None found, add some  Tokyo Movie Shinsha       Manga
#
#                     Duration                      Rating
# 48  DramaDrama, SportsSports  Combat SportsCombat Sports
#
# [1 rows x 22 columns]

# %%
dados.loc[idx_english][['Rank', 'Description', 'Synonyms','English', 'Type']]
# Out:
#    Rank                                        Description      Synonyms  \
# 5     6  Two years have passed following the Tendoshuu'...  銀魂 THE FINAL
#
#   English   Type
# 5     NaN  Movie

# %%
dados.loc[idx_type][['Rank', 'Description', 'Synonyms', 'English', 'Type']]
# Out:
#     Rank                                        Description     Synonyms  \
# 48    49  Yabuki Joe is left downhearted and hopeless af...  Rocky Joe 2
#
#              English Type
# 48  Tomorrow's Joe 2  NaN

# %%
dados.drop('Type', axis=1, inplace=True)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Score        1000 non-null   float64
#  1   Popularity   1000 non-null   int64
#  2   Rank         1000 non-null   int64
#  3   Members      1000 non-null   int64
#  4   Description  1000 non-null   object
#  5   Synonyms     1000 non-null   object
#  6   Japanese     1000 non-null   object
#  7   English      999 non-null    object
#  8   Eps          1000 non-null   object
#  9   Status       1000 non-null   object
#  10  Aired        1000 non-null   object
#  11  Premiered    1000 non-null   object
#  12  Broadcast    1000 non-null   object
#  13  Producers    1000 non-null   object
#  14  Licensors    1000 non-null   object
#  15  Studios      1000 non-null   object
#  16  Source       1000 non-null   object
#  17  Genres       1000 non-null   object
# ...

# %%
dados.loc[idx_english, 'English'] = 'Gintama: The Final'

# %%
dados.loc[idx_english][['Rank', 'Description', 'Synonyms','English']]
# Out:
#    Rank                                        Description      Synonyms  \
# 5     6  Two years have passed following the Tendoshuu'...  銀魂 THE FINAL
#
#               English
# 5  Gintama: The Final

# %%
dados.isnull().sum()
# Out:
# Score          0
# Popularity     0
# Rank           0
# Members        0
# Description    0
# Synonyms       0
# Japanese       0
# English        0
# Eps            0
# Status         0
# Aired          0
# Premiered      0
# Broadcast      0
# Producers      0
# Licensors      0
# Studios        0
# Source         0
# Genres         0
# Demographic    0
# Duration       0
# Rating         0
# dtype: int64

# %%
dados['English'].value_counts()
# Out:
# English
# TV                                    126
# Movie                                  50
# OVA                                    29
# ONA                                    17
# Special                                16
#                                      ...
# Black Butler: Book of the Atlantic      1
# Detektiv Conan: Episode - ONE           1
# Millennium Actress                      1
# Dororo                                  1
# Saint☆Young Men (Movie)                 1
# Name: count, Length: 738, dtype: int64
